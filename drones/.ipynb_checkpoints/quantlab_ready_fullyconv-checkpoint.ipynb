# %%
import numpy as np
import h5py
import torch
import torch.nn as nn
import torch
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def get_data(filename,train):
        with h5py.File(filename, 'r', libver='v112') as h5_file_handle:
            if train:
              image_train=np.array(h5_file_handle["/train/image"])
              full_pose_train=np.array(h5_file_handle["/train/xyzyaw_relative"])
              led_status_train=np.array(h5_file_handle["/train/led_status"])
              image_points_y=np.array(h5_file_handle["/train/image_points_y"])
              image_points_x=np.array(h5_file_handle["/train/image_points_x"])
            else:
              image_train=np.array(h5_file_handle["/test/image"])
              full_pose_train=np.array(h5_file_handle["/test/xyzyaw_relative"])
              led_status_train=np.array(h5_file_handle["/test/led_status"])
              image_points_y=np.array(h5_file_handle["/test/image_points_y"])
              image_points_x=np.array(h5_file_handle["/test/image_points_x"])
        x=image_points_y.reshape((-1,1))
        y=image_points_y.reshape((-1,1))
        im=image_train
        sz = 160
        X, Y = np.meshgrid(np.arange(sz),np.arange(sz))
        # out=np.empty((0,160,160), int)
        out =[]
        for element in range(image_points_y.shape[0]): 
          x, y = 150-image_points_y[element],160-image_points_x[element]
          D = ((X-x)**2 + (Y-y)**2)**0.5
          out_in=((1 - np.tanh((D-5)*0.08))/2).astype("float32")
          # out=np.append(out,out_in[None,:,:],axis=0)
          out.append(out_in[None,:,:])
        dist=full_pose_train.reshape((-1,4))[:,0].reshape(-1,1)
        led=led_status_train.reshape((-1,1))
        out=np.array(out)
        print(im.shape)
        print(out.shape)
        led=np.tile(np.expand_dims(np.expand_dims(led, axis=-1), axis=-1), [1,160,160])
        dist=np.tile(np.expand_dims(np.expand_dims(dist, axis=-1), axis=-1), [1,160,160])
        print(dist.shape)
        print(led.shape)
        y_train=np.concatenate((np.concatenate((out,led),axis=1),dist),axis=1)
        print(y_train.shape)

        return [im,y_train]

# %%
class MyDataset(Dataset):
    def __init__(self, x, y):
        self.x = torch.from_numpy(x).int()
        self.y = torch.from_numpy(y).float()
        
    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]
        
    def __len__(self):
        return len(self.x)

# %%
Mcalib = 1024
train_set = get_data("./content/datasets/dataset_train.h5",True)
# train_dataset = MyDataset(train_set[0], train_set[1])
calib_dataset = MyDataset(train_set[0][0:Mcalib], train_set[1][0:Mcalib])
# train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
calib_dataloader = DataLoader(calib_dataset, batch_size=32, shuffle=True)
# Out:
# (25887, 1, 160, 160)
# (25887, 1, 160, 160)
# (25887, 1, 160, 160)
# (25887, 1, 160, 160)
# (25887, 3, 160, 160)

# %%
def test_plot(dataloader):
    fig, axs = plt.subplots(3, 4, figsize=(15, 12))
    axs = axs.flatten()
    for i, (x, y) in enumerate(dataloader):
        if i%2==1:
          if i >= 12:
              break
          axs[i-1].imshow(x[0][0],cmap="gray")
          axs[i].imshow(y[0][0])
          print("dist:",y[0][2][0][0])
    plt.tight_layout()
    plt.show()

# %%
test_plot(train_dataloader)
# Out:
# dist: tensor(0.9583)
# dist: tensor(0.6152)
# dist: tensor(1.1768)
# dist: tensor(0.7716)
# dist: tensor(0.7438)
# dist: tensor(0.5765)

# %%
class MkModel(nn.Module):
    def __init__(self):
        super(MkModel, self).__init__()
        
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=8, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(8)
        self.relu1 = nn.ReLU()
        self.sep_conv1 = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(16)
        self.relu2 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2)
        self.sep_conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(32)
        self.relu3 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2)
        self.sep_conv3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(64)
        self.relu4 = nn.ReLU()
        self.pool3 = nn.MaxPool2d(kernel_size=2)
        self.sep_conv4 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1)
        self.bn5 = nn.BatchNorm2d(128)
        self.relu5 = nn.ReLU()
        self.conv2 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=1, padding=0)
        self.bn6 = nn.BatchNorm2d(128)
        self.relu6 = nn.ReLU()
        self.conv3 = nn.Conv2d(in_channels=128, out_channels=3, kernel_size=1, padding=0)
        self.bn7 = nn.BatchNorm2d(3)
        
    def forward(self, x):
        x = self.relu1(self.bn1(self.conv1(x)))
        x = self.relu2(self.bn2(self.sep_conv1(x)))
        x = self.relu3(self.bn3(self.sep_conv2(self.pool1(x))))
        x = self.relu4(self.bn4(self.sep_conv3(self.pool2(x))))
        x = self.relu5(self.bn5(self.sep_conv4(self.pool3(x))))
        x = self.relu6(self.bn6(self.conv2(x)))
        x = self.bn7(self.conv3(x))
        return x

# %%
model = MkModel()
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
def decompose(y_true, y_pred):
    # print(y_true.shape)
    # print(y_true.shape)
    # plt.imshow(y_true[0][0].cpu(),cmap="gray")
    # plt.show
    y_true_pos = torch.nn.functional.avg_pool2d(y_true[:,0,:,:], 8)
    y_true_dis = torch.nn.functional.avg_pool2d(y_true[:,2,:,:], 8)
    y_true_led = torch.nn.functional.avg_pool2d(y_true[:,1,:,:], 8)
    y_pred_pos = y_pred[:,0,:,:]
    y_pred_dis = y_pred[:,2,:,:]
    y_pred_led = y_pred[:,1,:,:]
    return y_true_pos, y_true_led, y_true_dis, y_pred_pos, y_pred_led, y_pred_dis

def pos_loss(y_true, y_pred):
    pos_true, led_true, dis_true, pos_pred, led_pred, dis_pred = decompose(y_true, y_pred)
    return torch.mean((pos_true - pos_pred) ** 2)

def led_loss(y_true, y_pred):
    pos_true, led_true, dis_true, pos_pred, led_pred, dis_pred = decompose(y_true, y_pred)
    led_sse = torch.sum(((led_true - led_pred) ** 2) * pos_true)
    return led_sse / torch.clamp(torch.sum(pos_true), min=0.001)

def dis_loss(y_true, y_pred):
    pos_true, led_true, dis_true, pos_pred, led_pred, dis_pred = decompose(y_true, y_pred)
    dis_true = torch.clamp(dis_true, min=0.1)
    dis_ssre = torch.sum((((dis_pred - dis_true) / dis_true) ** 2) * pos_true)
    return dis_ssre / torch.clamp(torch.sum(pos_true), min=0.001)

def total_loss(y_pred,y_true):
    return pos_loss(y_true, y_pred) + 0.01 * dis_loss(y_true, y_pred) + 0.01 * led_loss(y_true, y_pred)

# %%
model.load_state_dict(torch.load("./content/model.h5",map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
test_loss = 0.0
correct = 0
total = 0
model.eval()  # set model to evaluation mode

fig_in, ax_in = plt.subplots(11, 3, figsize=(30, 110))
ax_in = ax_in.flatten()

with torch.no_grad():
    # get a single batch of data from test dataloader
    data = next(iter(train_dataloader))
    inputs, labels = data
    inputs = inputs.to(device)
    labels = labels.to(device)
    outputs = model(inputs.float() / 255.0)
    outputs = outputs * torch.tensor([1., 1., 3.]).view(1, 3, 1, 1).to(outputs.device)
    loss = total_loss(outputs, labels)
    test_loss += loss.item()
    pos_true, led_true, dis_true, pos_pred, led_pred, dis_pred = decompose(labels,outputs)
    for i in range(0,inputs.shape[0],3):
        ax_in[i].imshow(inputs[i][0].cpu(),cmap="gray")
        ax_in[i+1].imshow(pos_true[i].cpu(),cmap="gray")
        ax_in[i+2].imshow(pos_pred[i].cpu(),cmap="gray")
    #   

print(f"Test loss: {test_loss}")

plt.tight_layout()
plt.show()
# Out:
# Test loss: 0.013140847906470299

# %%
import quantlib
import quantlib.algorithms as qa
import quantlib.editing.graphs as qg
import quantlib.editing.editing as qe
import quantlib.backends.dory as qd

# %%
model_fp = qg.fx.quantlib_symbolic_trace(root=model)

# Print the graph in tabular format
model_fp.graph.print_tabular()
# Out:
# opcode       name       target     args          kwargs
# -----------  ---------  ---------  ------------  --------
# placeholder  x          x          ()            {}
# call_module  conv1      conv1      (x,)          {}
# call_module  bn1        bn1        (conv1,)      {}
# call_module  relu1      relu1      (bn1,)        {}
# call_module  sep_conv1  sep_conv1  (relu1,)      {}
# call_module  bn2        bn2        (sep_conv1,)  {}
# call_module  relu2      relu2      (bn2,)        {}
# call_module  pool1      pool1      (relu2,)      {}
# call_module  sep_conv2  sep_conv2  (pool1,)      {}
# call_module  bn3        bn3        (sep_conv2,)  {}
# call_module  relu3      relu3      (bn3,)        {}
# call_module  pool2      pool2      (relu3,)      {}
# call_module  sep_conv3  sep_conv3  (pool2,)      {}
# call_module  bn4        bn4        (sep_conv3,)  {}
# call_module  relu4      relu4      (bn4,)        {}
# call_module  pool3      pool3      (relu4,)      {}
# call_module  sep_conv4  sep_conv4  (pool3,)      {}
# call_module  bn5        bn5        (sep_conv4,)  {}
# call_module  relu5      relu5      (bn5,)        {}
# call_module  conv2      conv2      (relu5,)      {}
# call_module  bn6        bn6        (conv2,)      {}
# call_module  relu6      relu6      (bn6,)        {}
# call_module  conv3      conv3      (relu6,)      {}
# call_module  bn7        bn7        (conv3,)      {}
# output       output     output     (bn7,)        {}

# %%
#float 2 fake
f2fconverter = qe.float2fake.F2F8bitPACTRoundingConverter()
model_fq = f2fconverter(model_fp)

# set validation state
model_fq.eval()
# Out:
# MkModel(
#   (conv1): PACTConv2d(1, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): PACTReLU()
#   (sep_conv1): PACTConv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): PACTReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (sep_conv2): PACTConv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): PACTReLU()
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (sep_conv3): PACTConv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu4): PACTReLU()
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (sep_conv4): PACTConv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu5): PACTReLU()
#   (conv2): PACTConv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu6): PACTReLU()
#   (conv3): PACTConv2d(128, 3, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn7): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
model_fq.graph.print_tabular()
# Out:
# opcode       name       target     args          kwargs
# -----------  ---------  ---------  ------------  --------
# placeholder  x          x          ()            {}
# call_module  conv1      conv1      (x,)          {}
# call_module  bn1        bn1        (conv1,)      {}
# call_module  relu1      relu1      (bn1,)        {}
# call_module  sep_conv1  sep_conv1  (relu1,)      {}
# call_module  bn2        bn2        (sep_conv1,)  {}
# call_module  relu2      relu2      (bn2,)        {}
# call_module  pool1      pool1      (relu2,)      {}
# call_module  sep_conv2  sep_conv2  (pool1,)      {}
# call_module  bn3        bn3        (sep_conv2,)  {}
# call_module  relu3      relu3      (bn3,)        {}
# call_module  pool2      pool2      (relu3,)      {}
# call_module  sep_conv3  sep_conv3  (pool2,)      {}
# call_module  bn4        bn4        (sep_conv3,)  {}
# call_module  relu4      relu4      (bn4,)        {}
# call_module  pool3      pool3      (relu4,)      {}
# call_module  sep_conv4  sep_conv4  (pool3,)      {}
# call_module  bn5        bn5        (sep_conv4,)  {}
# call_module  relu5      relu5      (bn5,)        {}
# call_module  conv2      conv2      (relu5,)      {}
# call_module  bn6        bn6        (conv2,)      {}
# call_module  relu6      relu6      (bn6,)        {}
# call_module  conv3      conv3      (relu6,)      {}
# call_module  bn7        bn7        (conv3,)      {}
# output       output     output     (bn7,)        {}

# %%
def validate(model, device, dataloader, verbose=True, integer=False):
    correct = 0
    total = 0
    test_loss = 0
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for data in dataloader:
            inputs, labels = data
            inputs = inputs.to(device)
            labels = labels.to(device)
            if integer:
                outputs = model(inputs.float())
            else:
                outputs = model(inputs.float() / 255.0)
            outputs = outputs * torch.tensor([1., 1., 3.]).view(1, 3, 1, 1).to(outputs.device)
            loss = total_loss(outputs, labels)
            test_loss += loss.item()
        print(f"Test loss: {test_loss/len(dataloader)}")
    return test_loss/len(dataloader)

# %%
valid_set = get_data("./content/datasets_test_hard/dataset_test_hard.h5",False)
valid_dataset = MyDataset(valid_set[0], valid_set[1])
valid_dataloader = DataLoader(valid_dataset, batch_size=32, shuffle=True)
# Out:
# (4634, 1, 160, 160)
# (4634, 1, 160, 160)
# (4634, 1, 160, 160)
# (4634, 1, 160, 160)
# (4634, 3, 160, 160)

# %%
with qe.float2fake.calibration(model_fq):
    acc = validate(model_fq, device, calib_dataloader)
# Out:
# Test loss: 0.008958537684520707

# %%
# adds rounding to all PACT operators
rounder =  qe.float2fake.F2F8bitPACTRounder()
model_fq_rounded = rounder(model_fq)
model_fq_rounded.to(device)
model_fq_rounded.eval()
# Out:
# MkModel(
#   (conv1): PACTConv2d(1, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): PACTReLU()
#   (sep_conv1): PACTConv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): PACTReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (sep_conv2): PACTConv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): PACTReLU()
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (sep_conv3): PACTConv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu4): PACTReLU()
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (sep_conv4): PACTConv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu5): PACTReLU()
#   (conv2): PACTConv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu6): PACTReLU()
#   (conv3): PACTConv2d(128, 3, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn7): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
acc = validate(model_fq_rounded, device, valid_dataloader)
print("\nFakeQuantized with calibration+rounding: loss: %.3f" % (acc))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-203dc6206ee9> in <module>
# ----> 1 acc = validate(model_fq_rounded, device, valid_dataloader)
#       2 print("\nFakeQuantized with calibration+rounding: loss: %.3f" % (acc))
#
# <ipython-input-19-d27a22dc9d72> in validate(model, device, dataloader, verbose, integer)
#      12                 outputs = model(inputs.float())
#      13             else:
# ---> 14                 outputs = model(inputs.float() / 255.0)
#      15             outputs = outputs * torch.tensor([1., 1., 3.]).view(1, 3, 1, 1).to(outputs.device)
#      16             loss = total_loss(outputs, labels)
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/torch/fx/graph_module.py in wrapped_call(self, *args, **kwargs)
#     503         def wrapped_call(self, *args, **kwargs):
#     504             try:
# --> 505                 return cls_call(self, *args, **kwargs)
#     506             except Exception as e:
#     507                 assert e.__traceback__
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/torch/fx/graph_module.py in wrapped_call(self, *args, **kwargs)
#     503         def wrapped_call(self, *args, **kwargs):
#     504             try:
# --> 505                 return cls_call(self, *args, **kwargs)
#     506             except Exception as e:
#     507                 assert e.__traceback__
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/torch/fx/graph_module.py in wrapped_call(self, *args, **kwargs)
#     503         def wrapped_call(self, *args, **kwargs):
#     504             try:
# --> 505                 return cls_call(self, *args, **kwargs)
#     506             except Exception as e:
#     507                 assert e.__traceback__
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/torch/fx/graph_module.py in wrapped_call(self, *args, **kwargs)
#     503         def wrapped_call(self, *args, **kwargs):
#     504             try:
# --> 505                 return cls_call(self, *args, **kwargs)
#     506             except Exception as e:
#     507                 assert e.__traceback__
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/torch/fx/graph_module.py in wrapped_call(self, *args, **kwargs)
#     503         def wrapped_call(self, *args, **kwargs):
#     504             try:
# --> 505                 return cls_call(self, *args, **kwargs)
#     506             except Exception as e:
#     507                 assert e.__traceback__
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/torch/fx/graph_module.py in wrapped_call(self, *args, **kwargs)
#     503         def wrapped_call(self, *args, **kwargs):
#     504             try:
# --> 505                 return cls_call(self, *args, **kwargs)
#     506             except Exception as e:
#     507                 assert e.__traceback__
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/torch/fx/graph_module.py in wrapped_call(self, *args, **kwargs)
#     503         def wrapped_call(self, *args, **kwargs):
#     504             try:
# --> 505                 return cls_call(self, *args, **kwargs)
#     506             except Exception as e:
#     507                 assert e.__traceback__
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/torch/fx/graph_module.py in wrapped_call(self, *args, **kwargs)
#     503         def wrapped_call(self, *args, **kwargs):
#     504             try:
# --> 505                 return cls_call(self, *args, **kwargs)
#     506             except Exception as e:
#     507                 assert e.__traceback__
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/torch/fx/graph_module.py in wrapped_call(self, *args, **kwargs)
#     503         def wrapped_call(self, *args, **kwargs):
#     504             try:
# --> 505                 return cls_call(self, *args, **kwargs)
#     506             except Exception as e:
#     507                 assert e.__traceback__
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/torch/fx/graph_module.py in wrapped_call(self, *args, **kwargs)
#     503         def wrapped_call(self, *args, **kwargs):
#     504             try:
# --> 505                 return cls_call(self, *args, **kwargs)
#     506             except Exception as e:
#     507                 assert e.__traceback__
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# <eval_with_key_81> in forward(self, x)
#       4     bn1 = self.bn1(conv1);  conv1 = None
#       5     relu1 = self.relu1(bn1);  bn1 = None
# ----> 6     sep_conv1 = self.sep_conv1(relu1);  relu1 = None
#       7     bn2 = self.bn2(sep_conv1);  sep_conv1 = None
#       8     relu2 = self.relu2(bn2);  bn2 = None
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/quantlib-0.2-py3.8.egg/quantlib/algorithms/qmodules/qmodules/qlinears.py in forward(self, x)
#     206             weight = self.weight
#     207
# --> 208         return F.conv2d(x, weight, self.bias, self.stride, self.padding, self.dilation, self.groups)
#     209
#     210     @classmethod
#
# KeyboardInterrupt:

# %%
x, _ = next(iter(valid_dataloader))
x=x.float()
x = x[0].unsqueeze(0)
print(x.dtype)
f2tconverter = qe.f2t.F2T24bitConverter()
model_tq = f2tconverter(model_fq_rounded, {'x': {'shape': x.shape, 'scale': torch.tensor((0.0039216,))}})
# Out:
# torch.float32

# %%
model_tq.graph.print_tabular()
# Out:
# opcode       name                                                   target                                             args                                                      kwargs
# -----------  -----------------------------------------------------  -------------------------------------------------  --------------------------------------------------------  --------
# placeholder  x                                                      x                                                  ()                                                        {}
# call_module  ql_eps_qconv2d_eps_integeriser_140163364807152__14_    QL_EpsQConv2dEpsIntegeriser_140163364807152__14_   (x,)                                                      {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140163364740112__6_  QL_EpsBN2dQReLUEpsRequantiser_140163364740112__6_  (ql_eps_qconv2d_eps_integeriser_140163364807152__14_,)    {}
# call_module  ql_eps_qconv2d_eps_integeriser_140163364807152__13_    QL_EpsQConv2dEpsIntegeriser_140163364807152__13_   (ql_eps_bn2d_qre_lueps_requantiser_140163364740112__6_,)  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140163364740112__5_  QL_EpsBN2dQReLUEpsRequantiser_140163364740112__5_  (ql_eps_qconv2d_eps_integeriser_140163364807152__13_,)    {}
# call_module  pool1                                                  pool1                                              (ql_eps_bn2d_qre_lueps_requantiser_140163364740112__5_,)  {}
# call_module  ql_eps_qconv2d_eps_integeriser_140163364807152__12_    QL_EpsQConv2dEpsIntegeriser_140163364807152__12_   (pool1,)                                                  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140163364740112__4_  QL_EpsBN2dQReLUEpsRequantiser_140163364740112__4_  (ql_eps_qconv2d_eps_integeriser_140163364807152__12_,)    {}
# call_module  pool2                                                  pool2                                              (ql_eps_bn2d_qre_lueps_requantiser_140163364740112__4_,)  {}
# call_module  ql_eps_qconv2d_eps_integeriser_140163364807152__11_    QL_EpsQConv2dEpsIntegeriser_140163364807152__11_   (pool2,)                                                  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140163364740112__3_  QL_EpsBN2dQReLUEpsRequantiser_140163364740112__3_  (ql_eps_qconv2d_eps_integeriser_140163364807152__11_,)    {}
# call_module  pool3                                                  pool3                                              (ql_eps_bn2d_qre_lueps_requantiser_140163364740112__3_,)  {}
# call_module  ql_eps_qconv2d_eps_integeriser_140163364807152__10_    QL_EpsQConv2dEpsIntegeriser_140163364807152__10_   (pool3,)                                                  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140163364740112__2_  QL_EpsBN2dQReLUEpsRequantiser_140163364740112__2_  (ql_eps_qconv2d_eps_integeriser_140163364807152__10_,)    {}
# call_module  ql_eps_qconv2d_eps_integeriser_140163364807152__9_     QL_EpsQConv2dEpsIntegeriser_140163364807152__9_    (ql_eps_bn2d_qre_lueps_requantiser_140163364740112__2_,)  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140163364740112__1_  QL_EpsBN2dQReLUEpsRequantiser_140163364740112__1_  (ql_eps_qconv2d_eps_integeriser_140163364807152__9_,)     {}
# call_module  ql_eps_qconv2d_eps_integeriser_140163364807152__8_     QL_EpsQConv2dEpsIntegeriser_140163364807152__8_    (ql_eps_bn2d_qre_lueps_requantiser_140163364740112__1_,)  {}
# call_module  ql_eps_tunnel_inserter_140153714956368__17_            QL_EpsTunnelInserter_140153714956368__17_          (ql_eps_qconv2d_eps_integeriser_140163364807152__8_,)     {}
# call_module  bn7                                                    bn7                                                (ql_eps_tunnel_inserter_140153714956368__17_,)            {}
# output       output                                                 output                                             (bn7,)                                                    {}

# %%
# Test the network
acc = validate(model_tq, device, valid_dataloader, integer=True)
print("\nTrueQuantized: accuracy: %.3f" % (acc))
# Out:
# Test loss: 0.017122979693371673
#
# TrueQuantized: accuracy: 0.017

# %%
epsremover = qe.f2t.FinalEpsTunnelRemover()
model_tq_removed = epsremover(model_tq)
model_tq_removed.graph.print_tabular()
# Out:
# opcode       name                                                   target                                             args                                                      kwargs
# -----------  -----------------------------------------------------  -------------------------------------------------  --------------------------------------------------------  --------
# placeholder  x                                                      x                                                  ()                                                        {}
# call_module  ql_eps_qconv2d_eps_integeriser_140163364807152__14_    QL_EpsQConv2dEpsIntegeriser_140163364807152__14_   (x,)                                                      {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140163364740112__6_  QL_EpsBN2dQReLUEpsRequantiser_140163364740112__6_  (ql_eps_qconv2d_eps_integeriser_140163364807152__14_,)    {}
# call_module  ql_eps_qconv2d_eps_integeriser_140163364807152__13_    QL_EpsQConv2dEpsIntegeriser_140163364807152__13_   (ql_eps_bn2d_qre_lueps_requantiser_140163364740112__6_,)  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140163364740112__5_  QL_EpsBN2dQReLUEpsRequantiser_140163364740112__5_  (ql_eps_qconv2d_eps_integeriser_140163364807152__13_,)    {}
# call_module  pool1                                                  pool1                                              (ql_eps_bn2d_qre_lueps_requantiser_140163364740112__5_,)  {}
# call_module  ql_eps_qconv2d_eps_integeriser_140163364807152__12_    QL_EpsQConv2dEpsIntegeriser_140163364807152__12_   (pool1,)                                                  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140163364740112__4_  QL_EpsBN2dQReLUEpsRequantiser_140163364740112__4_  (ql_eps_qconv2d_eps_integeriser_140163364807152__12_,)    {}
# call_module  pool2                                                  pool2                                              (ql_eps_bn2d_qre_lueps_requantiser_140163364740112__4_,)  {}
# call_module  ql_eps_qconv2d_eps_integeriser_140163364807152__11_    QL_EpsQConv2dEpsIntegeriser_140163364807152__11_   (pool2,)                                                  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140163364740112__3_  QL_EpsBN2dQReLUEpsRequantiser_140163364740112__3_  (ql_eps_qconv2d_eps_integeriser_140163364807152__11_,)    {}
# call_module  pool3                                                  pool3                                              (ql_eps_bn2d_qre_lueps_requantiser_140163364740112__3_,)  {}
# call_module  ql_eps_qconv2d_eps_integeriser_140163364807152__10_    QL_EpsQConv2dEpsIntegeriser_140163364807152__10_   (pool3,)                                                  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140163364740112__2_  QL_EpsBN2dQReLUEpsRequantiser_140163364740112__2_  (ql_eps_qconv2d_eps_integeriser_140163364807152__10_,)    {}
# call_module  ql_eps_qconv2d_eps_integeriser_140163364807152__9_     QL_EpsQConv2dEpsIntegeriser_140163364807152__9_    (ql_eps_bn2d_qre_lueps_requantiser_140163364740112__2_,)  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140163364740112__1_  QL_EpsBN2dQReLUEpsRequantiser_140163364740112__1_  (ql_eps_qconv2d_eps_integeriser_140163364807152__9_,)     {}
# call_module  ql_eps_qconv2d_eps_integeriser_140163364807152__8_     QL_EpsQConv2dEpsIntegeriser_140163364807152__8_    (ql_eps_bn2d_qre_lueps_requantiser_140163364740112__1_,)  {}
# call_module  ql_eps_tunnel_inserter_140153714956368__17_            QL_EpsTunnelInserter_140153714956368__17_          (ql_eps_qconv2d_eps_integeriser_140163364807152__8_,)     {}
# call_module  bn7                                                    bn7                                                (ql_eps_tunnel_inserter_140153714956368__17_,)            {}
# output       output                                                 output                                             (bn7,)                                                    {}

# %%
test_loss = 0.0
correct = 0
total = 0
model_tq_removed.eval()  # set model to evaluation mode


fig_in, ax_in = plt.subplots(11, 3, figsize=(30, 110))
ax_in = ax_in.flatten()

with torch.no_grad():
    # get a single batch of data from test dataloader
    data = next(iter(valid_dataloader))
    inputs, labels = data
    inputs = inputs.to(device)
    labels = labels.to(device)
    outputs = model_tq_removed(inputs.float())
    outputs = outputs * torch.tensor([1., 1., 3.]).view(1, 3, 1, 1).to(outputs.device)
    loss = total_loss(outputs, labels)
    test_loss += loss.item()
    pos_true, led_true, dis_true, pos_pred, led_pred, dis_pred = decompose(labels,outputs)
    for i in range(0,inputs.shape[0],3):
        ax_in[i].imshow(inputs[i][0].cpu(),cmap="gray")
        ax_in[i+1].imshow(pos_true[i].cpu(),cmap="gray")
        ax_in[i+2].imshow(pos_pred[i].cpu(),cmap="gray")
    #   

print(f"Test loss: {test_loss}")

plt.tight_layout()
plt.show()
# Out:
# Test loss: 0.017629627138376236

# %%
print(model_tq_removed)
# Out:
# MkModel(
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (bn7): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (QL_EpsTunnelInserter_140153714956368__17_): EpsTunnel()
#   (QL_EpsQConv2dEpsIntegeriser_140163364807152__8_): Conv2d(128, 3, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (QL_EpsQConv2dEpsIntegeriser_140163364807152__9_): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (QL_EpsQConv2dEpsIntegeriser_140163364807152__10_): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (QL_EpsQConv2dEpsIntegeriser_140163364807152__11_): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (QL_EpsQConv2dEpsIntegeriser_140163364807152__12_): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (QL_EpsQConv2dEpsIntegeriser_140163364807152__13_): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (QL_EpsQConv2dEpsIntegeriser_140163364807152__14_): Conv2d(1, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (QL_EpsBN2dQReLUEpsRequantiser_140163364740112__1_): Requantisation()
#   (QL_EpsBN2dQReLUEpsRequantiser_140163364740112__2_): Requantisation()
#   (QL_EpsBN2dQReLUEpsRequantiser_140163364740112__3_): Requantisation()
#   (QL_EpsBN2dQReLUEpsRequantiser_140163364740112__4_): Requantisation()
#   (QL_EpsBN2dQReLUEpsRequantiser_140163364740112__5_): Requantisation()
#   (QL_EpsBN2dQReLUEpsRequantiser_140163364740112__6_): Requantisation()
# )
#
# def forward(self, x):
#     ql_eps_qconv2d_eps_integeriser_140163364807152__14_ = self.QL_EpsQConv2dEpsIntegeriser_140163364807152__14_(x);  x = None
#     ql_eps_bn2d_qre_lueps_requantiser_140163364740112__6_ = self.QL_EpsBN2dQReLUEpsRequantiser_140163364740112__6_(ql_eps_qconv2d_eps_integeriser_140163364807152__14_);  ql_eps_qconv2d_eps_integeriser_140163364807152__14_ = None
#     ql_eps_qconv2d_eps_integeriser_140163364807152__13_ = self.QL_EpsQConv2dEpsIntegeriser_140163364807152__13_(ql_eps_bn2d_qre_lueps_requantiser_140163364740112__6_);  ql_eps_bn2d_qre_lueps_requantiser_140163364740112__6_ = None
#     ql_eps_bn2d_qre_lueps_requantiser_140163364740112__5_ = self.QL_EpsBN2dQReLUEpsRequantiser_140163364740112__5_(ql_eps_qconv2d_eps_integeriser_140163364807152__13_);  ql_eps_qconv2d_eps_integeriser_140163364807152__13_ = None
#     pool1 = self.pool1(ql_eps_bn2d_qre_lueps_requantiser_140163364740112__5_);  ql_eps_bn2d_qre_lueps_requantiser_140163364740112__5_ = None
#     ql_eps_qconv2d_eps_integeriser_140163364807152__12_ = self.QL_EpsQConv2dEpsIntegeriser_140163364807152__12_(pool1);  pool1 = None
#     ql_eps_bn2d_qre_lueps_requantiser_140163364740112__4_ = self.QL_EpsBN2dQReLUEpsRequantiser_140163364740112__4_(ql_eps_qconv2d_eps_integeriser_140163364807152__12_);  ql_eps_qconv2d_eps_integeriser_140163364807152__12_ = None
#     pool2 = self.pool2(ql_eps_bn2d_qre_lueps_requantiser_140163364740112__4_);  ql_eps_bn2d_qre_lueps_requantiser_140163364740112__4_ = None
#     ql_eps_qconv2d_eps_integeriser_140163364807152__11_ = self.QL_EpsQConv2dEpsIntegeriser_140163364807152__11_(pool2);  pool2 = None
#     ql_eps_bn2d_qre_lueps_requantiser_140163364740112__3_ = self.QL_EpsBN2dQReLUEpsRequantiser_140163364740112__3_(ql_eps_qconv2d_eps_integeriser_140163364807152__11_);  ql_eps_qconv2d_eps_integeriser_140163364807152__11_ = None
#     pool3 = self.pool3(ql_eps_bn2d_qre_lueps_requantiser_140163364740112__3_);  ql_eps_bn2d_qre_lueps_requantiser_140163364740112__3_ = None
#     ql_eps_qconv2d_eps_integeriser_140163364807152__10_ = self.QL_EpsQConv2dEpsIntegeriser_140163364807152__10_(pool3);  pool3 = None
#     ql_eps_bn2d_qre_lueps_requantiser_140163364740112__2_ = self.QL_EpsBN2dQReLUEpsRequantiser_140163364740112__2_(ql_eps_qconv2d_eps_integeriser_140163364807152__10_);  ql_eps_qconv2d_eps_integeriser_140163364807152__10_ = None
#     ql_eps_qconv2d_eps_integeriser_140163364807152__9_ = self.QL_EpsQConv2dEpsIntegeriser_140163364807152__9_(ql_eps_bn2d_qre_lueps_requantiser_140163364740112__2_);  ql_eps_bn2d_qre_lueps_requantiser_140163364740112__2_ = None
#     ql_eps_bn2d_qre_lueps_requantiser_140163364740112__1_ = self.QL_EpsBN2dQReLUEpsRequantiser_140163364740112__1_(ql_eps_qconv2d_eps_integeriser_140163364807152__9_);  ql_eps_qconv2d_eps_integeriser_140163364807152__9_ = None
#     ql_eps_qconv2d_eps_integeriser_140163364807152__8_ = self.QL_EpsQConv2dEpsIntegeriser_140163364807152__8_(ql_eps_bn2d_qre_lueps_requantiser_140163364740112__1_);  ql_eps_bn2d_qre_lueps_requantiser_140163364740112__1_ = None
#     ql_eps_tunnel_inserter_140153714956368__17_ = self.QL_EpsTunnelInserter_140153714956368__17_(ql_eps_qconv2d_eps_integeriser_140163364807152__8_);  ql_eps_qconv2d_eps_integeriser_140163364807152__8_ = None
#     bn7 = self.bn7(ql_eps_tunnel_inserter_140153714956368__17_);  ql_eps_tunnel_inserter_140153714956368__17_ = None
#     return bn7

# %%
doryexporter = qd.DORYExporter()
doryexporter.export(model_tq_removed, x.shape, ".")
doryexporter.dump_features(model_tq, x, ".")

# %%
mgX40, mgY40 = np.meshgrid(np.linspace(0,1,20), np.linspace(0,1,20))
def postprocess_simple_batch(labels, outputs):
    pos_true, led_true, dis_true, pos_predi, led_predi, dis_predi = decompose(labels,outputs)
    pos_truei=pos_true.cpu().detach().numpy()
    led_truei=led_true.cpu().detach().numpy()
    dis_truei=dis_true.cpu().detach().numpy()
    pos_predi=pos_predi.cpu().detach().numpy()
    led_predi=led_predi.cpu().detach().numpy()
    dis_predi=dis_predi.cpu().detach().numpy()

    # a=dis_pred[i]*pos_pred[i]
    # a=a.cpu().detach().numpy()
    # b=pos_pred[i].cpu().detach().numpy()
    # dis_pred_val = np.sum(a)/np.sum(b)
    threshold = np.max(pos_predi, axis = (1,2), keepdims = True) * .4
    # print(threshold)
    pos_predi -= threshold
    np.clip(pos_predi, 0, threshold, out = pos_predi)
    pos_predj=pos_predi
    # print(np.sum(dis_predi * pos_predi, axis=(1,2))/np.sum(pos_predi, axis=(1,2)))
    # print(np.sum(dis_truei * pos_truei, axis=(1,2))/np.sum(pos_truei, axis=(1,2)))
  
    
    # print(dis_true)
    ret = dict(
        x_pred = np.sum(mgX40[np.newaxis,:,:] * pos_predi, axis=(1,2))/np.sum(pos_predi, axis=(1,2)) * 160,
        y_pred = np.sum(mgY40[np.newaxis,:,:] * pos_predi, axis=(1,2))/np.sum(pos_predi, axis=(1,2)) * 160,
        led_pred = np.sum(led_predi * pos_predj, axis=(1,2))/np.sum(pos_predj, axis=(1,2)),
        dis_pred = np.sum(dis_predi * pos_predj, axis=(1,2))/np.sum(pos_predj, axis=(1,2)),
        pred_confidence = np.max(pos_predi, axis=(1,2)),
        x_true = np.sum(mgX40[np.newaxis,:,:] * pos_truei, axis=(1,2))/np.sum(pos_truei, axis=(1,2)) * 160,
        y_true = np.sum(mgY40[np.newaxis,:,:] * pos_truei, axis=(1,2))/np.sum(pos_truei, axis=(1,2)) * 160,
        led_true = np.sum(led_truei * pos_truei, axis=(1,2))/np.sum(pos_truei, axis=(1,2)),
        dis_true = np.sum(dis_truei * pos_truei, axis=(1,2))/np.sum(pos_truei, axis=(1,2)),
    )
    return [dict(zip(ret,t)) for t in zip(*ret.values())]

# %%
data_out = []
with torch.no_grad():
    for data in valid_dataloader:
        inputs, labels = data
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model_tq_removed(inputs.float())
        outputs = outputs * torch.tensor([1., 1., 3.]).view(1, 3, 1, 1).to(outputs.device)
        data_out += postprocess_simple_batch(labels,outputs)

# %%
import pandas as pd
df = pd.DataFrame(data_out)
df["y_zone"] = (df["y_true"]/320*3).astype(int)
df["pred_confidence_bin"] = (df["pred_confidence"]*2.99).astype(int)

# %%
import sklearn
import sklearn.metrics
fig,axs = plt.subplots(ncols=3, figsize=(10,3))
alpha = 0.1
axs[0].scatter(df["x_true"],df["x_pred"], s=1, marker='.', alpha=alpha)
axs[0].plot([0,160],[0,160],'k:')
axs[0].set_title(f"x: R2 {sklearn.metrics.r2_score(df['x_true'],df['x_pred']):.03f}")
axs[1].scatter(df["y_true"],df["y_pred"], s=1, marker='.', alpha=alpha)
axs[1].plot([0,160],[0,160],'k:')
axs[1].set_title(f"y: R2 {sklearn.metrics.r2_score(df['y_true'],df['y_pred']):.03f}")
axs[2].scatter(df["dis_true"],df["dis_pred"], s=1, marker='.', alpha=alpha)
axs[2].plot([0.4,1.6],[0.4,1.6],'k:')
axs[2].set_title(f"d: R2 {sklearn.metrics.r2_score(df['dis_true'],df['dis_pred']):.03f}")
# Out:
# Text(0.5, 1.0, 'd: R2 0.211')

# %%
import matplotlib
from matplotlib.pyplot import figure
font = {'family' : 'normal',
'weight' : 'bold',
'size'   : 14}

matplotlib.rc('font', **font)
figure(figsize=(8,8), dpi=80)
plt.title("distance")
plt.xlim([0.2, 1.6])
plt.ylim([0.2, 1.6])
plt.plot(df["dis_true"],df["dis_true"], c ="green")
plt.scatter(df["dis_true"],df["dis_pred"], c ="red", alpha=0.1)
plt.show()
figure(figsize=(8,8), dpi=80)
plt.title("y image")
plt.xlim([0, 160])
plt.ylim([0, 160])
plt.plot(df["y_true"],df["y_true"], c ="green")
plt.scatter(df["y_true"], df["y_pred"], c ="red", alpha=0.1)
plt.show()
figure(figsize=(8,8), dpi=80)
plt.title("x image")
plt.xlim([0, 160])
plt.ylim([0, 160])
plt.plot(df["x_true"], df["x_true"], c ="green")
plt.scatter(df["x_true"], df["x_pred"], c ="red", alpha=0.1)
plt.show()
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
