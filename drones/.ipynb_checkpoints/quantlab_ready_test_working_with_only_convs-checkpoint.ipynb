# %%
import numpy as np
import h5py
import torch
import torch.nn as nn
import torch
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def get_data(filename,train,calib,size):
        with h5py.File(filename, 'r', libver='v112') as h5_file_handle:
            if train:
              image_train=np.array(h5_file_handle["/train/image"])
              full_pose_train=np.array(h5_file_handle["/train/xyzyaw_relative"])
              led_status_train=np.array(h5_file_handle["/train/led_status"])
              image_points_y=np.array(h5_file_handle["/train/image_points_y"])
              image_points_x=np.array(h5_file_handle["/train/image_points_x"])
            else:
              image_train=np.array(h5_file_handle["/test/image"])
              full_pose_train=np.array(h5_file_handle["/test/xyzyaw_relative"])
              led_status_train=np.array(h5_file_handle["/test/led_status"])
              image_points_y=np.array(h5_file_handle["/test/image_points_y"])
              image_points_x=np.array(h5_file_handle["/test/image_points_x"])
        x=image_points_y.reshape((-1,1))
        y=image_points_y.reshape((-1,1))
        sz = 160
        X, Y = np.meshgrid(np.arange(sz),np.arange(sz))
        # out=np.empty((0,160,160), int)
        out =[]
        for element in range(image_points_y.shape[0]): 
          x, y = 150-image_points_y[element],160-image_points_x[element]
          D = ((X-x)**2 + (Y-y)**2)**0.5
          out_in=((1 - np.tanh((D-5)*0.08))/2).astype("float32")
          # out=np.append(out,out_in[None,:,:],axis=0)
          out.append(out_in[None,:,:])
        if(calib):
            im=image_train[0:size]
            dist=full_pose_train.reshape((-1,4))[:,0].reshape(-1,1)[0:size]
            led=led_status_train.reshape((-1,1))[0:size]
            out=np.array(out)[0:size]
        else:
            im=image_train
            dist=full_pose_train.reshape((-1,4))[:,0].reshape(-1,1)
            led=led_status_train.reshape((-1,1))
            out=np.array(out)
        print(im.shape)
        print(out.shape)
        led=np.tile(np.expand_dims(np.expand_dims(led, axis=-1), axis=-1), [1,160,160])
        dist=np.tile(np.expand_dims(np.expand_dims(dist, axis=-1), axis=-1), [1,160,160])
        print(dist.shape)
        print(led.shape)
        y_train=np.concatenate((np.concatenate((out,led),axis=1),dist),axis=1)
        print(y_train.shape)
        

        return [im,y_train]

# %%
class MyDataset(Dataset):
    def __init__(self, x, y):
        self.x = torch.from_numpy(x).int()
        self.y = torch.from_numpy(y).float()
        
    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]
        
    def __len__(self):
        return len(self.x)

# %%
Mcalib = 1024
calib_set = get_data("./content/datasets/dataset_train.h5",True,True,4096)
# train_set = get_data("./content/datasets/dataset_train.h5",True,False)
# train_dataset = MyDataset(train_set[0], train_set[1])
calib_dataset = MyDataset(calib_set[0], calib_set[1])
# train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
calib_dataloader = DataLoader(calib_dataset, batch_size=32, shuffle=True)
# Out:
# (4096, 1, 160, 160)
# (4096, 1, 160, 160)
# (4096, 1, 160, 160)
# (4096, 1, 160, 160)
# (4096, 3, 160, 160)

# %%
def test_plot(dataloader):
    fig, axs = plt.subplots(3, 4, figsize=(15, 12))
    axs = axs.flatten()
    for i, (x, y) in enumerate(dataloader):
        if i%2==1:
          if i >= 12:
              break
          axs[i-1].imshow(x[0][0],cmap="gray")
          axs[i].imshow(y[0][0])
          print("dist:",y[0][2][0][0])
    plt.tight_layout()
    plt.show()

# %%
test_plot(calib_dataloader)
# Out:
# dist: tensor(1.4842)
# dist: tensor(1.2592)
# dist: tensor(0.4487)
# dist: tensor(1.2097)
# dist: tensor(1.2118)
# dist: tensor(1.4008)

# %%
# class MkModel(nn.Module):
#     def __init__(self):
#         super(MkModel, self).__init__()
        
#         self.conv1 = nn.Conv2d(in_channels=1, out_channels=8, kernel_size=3, padding=1)
#         self.bn1 = nn.BatchNorm2d(8)
#         self.relu1 = nn.ReLU()
#         self.sep_conv1 = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, padding=1)
#         self.bn2 = nn.BatchNorm2d(16)
#         self.relu2 = nn.ReLU()
#         self.pool1 = nn.MaxPool2d(kernel_size=2)
#         self.sep_conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding=1)
#         self.bn3 = nn.BatchNorm2d(32)
#         self.relu3 = nn.ReLU()
#         self.pool2 = nn.MaxPool2d(kernel_size=2)
#         self.sep_conv3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
#         self.bn4 = nn.BatchNorm2d(64)
#         self.relu4 = nn.ReLU()
#         self.pool3 = nn.MaxPool2d(kernel_size=2)
#         self.sep_conv4 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1)
#         self.bn5 = nn.BatchNorm2d(128)
#         self.relu5 = nn.ReLU()
#         self.conv2 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=1, padding=0)
#         self.bn6 = nn.BatchNorm2d(128)
#         self.relu6 = nn.ReLU()
#         self.conv3 = nn.Conv2d(in_channels=128, out_channels=4, kernel_size=1, padding=0)
#         self.bn7 = nn.BatchNorm2d(4)
#         self.relu7 = nn.ReLU()
        
#     def forward(self, x):
#         x = self.relu1(self.bn1(self.conv1(x)))
#         print(x.shape)
#         x = self.relu2(self.bn2(self.sep_conv1(x)))
#         print(x.shape)
#         x = self.relu3(self.bn3(self.sep_conv2(self.pool1(x))))
#         print(x.shape)
#         x = self.relu4(self.bn4(self.sep_conv3(self.pool2(x))))
#         print(x.shape)
#         x = self.relu5(self.bn5(self.sep_conv4(self.pool3(x))))
#         print(x.shape)
#         x = self.relu6(self.bn6(self.conv2(x)))
#         print(x.shape)
#         x = self.relu7(self.bn7(self.conv3(x)))
#         print(x.shape)
#         return x

# %%
class Mk_Model_attempt(nn.Module):
    def __init__(self):
        super(Mk_Model_attempt, self).__init__()
        activation_class = nn.ReLU
        self.block1 = Mk_Model_attempt.make_pilot1(activation_class)
        self.avgpool1 = Mk_Model_attempt.make_avgpool()
        self.block2 = Mk_Model_attempt.make_pilot2(activation_class)
        self.avgpool2 = Mk_Model_attempt.make_avgpool()
        self.block3 = Mk_Model_attempt.make_pilot3(activation_class)
        self.avgpool3 = Mk_Model_attempt.make_avgpool()
        self.block4 = Mk_Model_attempt.make_pilot4(activation_class)
    
    @staticmethod
    def make_pilot1(activation_class: type) -> nn.Sequential:
        modules = []
        modules += Mk_Model_attempt.make_standard_convolution_layer(in_channels=1,out_channels=8,kernel_size=3,padding=1,activation_class=activation_class)
        modules += Mk_Model_attempt.make_standard_convolution_layer(in_channels=8,out_channels=16,kernel_size=3,padding=1,activation_class=activation_class)
        return nn.Sequential(*modules)
    
    @staticmethod
    def make_pilot2(activation_class: type) -> nn.Sequential:
        modules = []
        modules += Mk_Model_attempt.make_standard_convolution_layer(in_channels=16,out_channels=32,kernel_size=3,padding=1,activation_class=activation_class)
        return nn.Sequential(*modules)
        
    @staticmethod
    def make_pilot3(activation_class: type) -> nn.Sequential:
        modules = []
        modules += Mk_Model_attempt.make_standard_convolution_layer(in_channels=32,out_channels=64,kernel_size=3,padding=1,activation_class=activation_class)
        return nn.Sequential(*modules)
    
    @staticmethod
    def make_pilot4(activation_class: type) -> nn.Sequential:
        modules = []
        modules += Mk_Model_attempt.make_standard_convolution_layer(in_channels=64,out_channels=128,kernel_size=3,padding=1,activation_class=activation_class)
        modules += Mk_Model_attempt.make_standard_convolution_layer(in_channels=128,out_channels=128,kernel_size=1,padding=1,activation_class=activation_class)
        modules += Mk_Model_attempt.make_standard_convolution_layer(in_channels=128,out_channels=4,kernel_size=1,padding=1,activation_class=activation_class)
        return nn.Sequential(*modules)
        
    @staticmethod
    def make_avgpool() -> nn.AdaptiveAvgPool2d:
        return nn.AdaptiveAvgPool2d((2, 2))
    
    @staticmethod
    def make_standard_convolution_layer(in_channels:      int,
                                            out_channels:     int,
                                            kernel_size:    int,
                                            padding:      int,
                                            activation_class: type) -> nn.Sequential:

            modules = []

            modules += [nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size, padding=padding, bias=False)]
            modules += [nn.BatchNorm2d(out_channels)]
            modules += [activation_class(inplace=True)]

            return nn.Sequential(*modules)
    
    
        
    def forward(self, x):
        x = self.block1(x)
        print(x.shape)
        x = self.avgpool1(x)
        print(x.shape)
        x = self.block2(x)
        print(x.shape)
        x = self.avgpool2(x)
        print(x.shape)
        x = self.block3(x)
        print(x.shape)
        x = self.avgpool3(x)
        print(x.shape)
        x = self.block4(x)
        print(x.shape)
        return x

# %%
# model = MkModel()
# criterion = nn.MSELoss()
# optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
model = Mk_Model_attempt()
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
def decompose(y_true, y_pred):
    # print(y_true.shape)
    # print(y_true.shape)
    # plt.imshow(y_true[0][0].cpu(),cmap="gray")
    # plt.show
    y_true_pos = torch.nn.functional.avg_pool2d(y_true[:,0,:,:], 8)
    y_true_dis = torch.nn.functional.avg_pool2d(y_true[:,2,:,:], 8)
    y_true_led = torch.nn.functional.avg_pool2d(y_true[:,1,:,:], 8)
    y_pred_pos = y_pred[:,0,:,:]
    y_pred_dis = y_pred[:,2,:,:]
    y_pred_led = y_pred[:,1,:,:]
#     print(y_pred_pos.shape)
    return y_true_pos, y_true_led, y_true_dis, y_pred_pos, y_pred_led, y_pred_dis

def pos_loss(y_true, y_pred):
    pos_true, led_true, dis_true, pos_pred, led_pred, dis_pred = decompose(y_true, y_pred)
    return torch.mean((pos_true - pos_pred) ** 2)

def led_loss(y_true, y_pred):
    pos_true, led_true, dis_true, pos_pred, led_pred, dis_pred = decompose(y_true, y_pred)
    led_sse = torch.sum(((led_true - led_pred) ** 2) * pos_true)
    return led_sse / torch.clamp(torch.sum(pos_true), min=0.001)

def dis_loss(y_true, y_pred):
    pos_true, led_true, dis_true, pos_pred, led_pred, dis_pred = decompose(y_true, y_pred)
    dis_true = torch.clamp(dis_true, min=0.1)
    dis_ssre = torch.sum((((dis_pred - dis_true) / dis_true) ** 2) * pos_true)
    return dis_ssre / torch.clamp(torch.sum(pos_true), min=0.001)

def total_loss(y_pred,y_true):
    return pos_loss(y_true, y_pred) + 0.01 * dis_loss(y_true, y_pred) + 0.01 * led_loss(y_true, y_pred)

# %%
model.load_state_dict(torch.load("./content/model.h5",map_location=torch.device('cpu')))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-106-82389dc3b2ef> in <module>
# ----> 1 model.load_state_dict(torch.load("./content/model.h5",map_location=torch.device('cpu')))
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#    1404
#    1405         if len(error_msgs) > 0:
# -> 1406             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    1407                                self.__class__.__name__, "\n\t".join(error_msgs)))
#    1408         return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for Mk_Model_attempt:
# 	Missing key(s) in state_dict: "block1.0.weight", "block1.1.weight", "block1.1.bias", "block1.1.running_mean", "block1.1.running_var", "block1.3.weight", "block1.4.weight", "block1.4.bias", "block1.4.running_mean", "block1.4.running_var", "block2.0.weight", "block2.1.weight", "block2.1.bias", "block2.1.running_mean", "block2.1.running_var", "block3.0.weight", "block3.1.weight", "block3.1.bias", "block3.1.running_mean", "block3.1.running_var", "block4.0.weight", "block4.1.weight", "block4.1.bias", "block4.1.running_mean", "block4.1.running_var", "block4.3.weight", "block4.4.weight", "block4.4.bias", "block4.4.running_mean", "block4.4.running_var", "block4.6.weight", "block4.7.weight", "block4.7.bias", "block4.7.running_mean", "block4.7.running_var".
# 	Unexpected key(s) in state_dict: "conv1.weight", "conv1.bias", "bn1.weight", "bn1.bias", "bn1.running_mean", "bn1.running_var", "bn1.num_batches_tracked", "sep_conv1.weight", "sep_conv1.bias", "bn2.weight", "bn2.bias", "bn2.running_mean", "bn2.running_var", "bn2.num_batches_tracked", "sep_conv2.weight", "sep_conv2.bias", "bn3.weight", "bn3.bias", "bn3.running_mean", "bn3.running_var", "bn3.num_batches_tracked", "sep_conv3.weight", "sep_conv3.bias", "bn4.weight", "bn4.bias", "bn4.running_mean", "bn4.running_var", "bn4.num_batches_tracked", "sep_conv4.weight", "sep_conv4.bias", "bn5.weight", "bn5.bias", "bn5.running_mean", "bn5.running_var", "bn5.num_batches_tracked", "conv2.weight", "conv2.bias", "bn6.weight", "bn6.bias", "bn6.running_mean", "bn6.running_var", "bn6.num_batches_tracked", "conv3.weight", "conv3.bias", "bn7.weight", "bn7.bias", "bn7.running_mean", "bn7.running_var", "bn7.num_batches_tracked".

# %%
test_loss = 0.0
correct = 0
total = 0
model.eval()  # set model to evaluation mode

fig_in, ax_in = plt.subplots(11, 3, figsize=(30, 110))
ax_in = ax_in.flatten()

with torch.no_grad():
    # get a single batch of data from test dataloader
    data = next(iter(calib_dataloader))
    inputs, labels = data
    inputs = inputs.to(device)
    labels = labels.to(device)
    outputs = model(inputs.float() / 255.0)
    outputs = outputs * torch.tensor([1., 1., 3., 1.]).view(1, 4, 1, 1).to(outputs.device)
    loss = total_loss(outputs, labels)
    test_loss += loss.item()
    pos_true, led_true, dis_true, pos_pred, led_pred, dis_pred = decompose(labels,outputs)
    for i in range(0,inputs.shape[0],3):
        ax_in[i].imshow(inputs[i][0].cpu(),cmap="gray")
        ax_in[i+1].imshow(pos_true[i].cpu(),cmap="gray")
        ax_in[i+2].imshow(pos_pred[i].cpu(),cmap="gray")
    #   

print(f"Test loss: {test_loss}")

plt.tight_layout()
plt.show()
# Out:
# torch.Size([32, 16, 160, 160])
# torch.Size([32, 16, 2, 2])
# torch.Size([32, 32, 2, 2])
# torch.Size([32, 32, 2, 2])
# torch.Size([32, 64, 2, 2])
# torch.Size([32, 64, 2, 2])
# torch.Size([32, 4, 6, 6])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-118-f5f643636d06> in <module>
#      15     outputs = model(inputs.float() / 255.0)
#      16     outputs = outputs * torch.tensor([1., 1., 3., 1.]).view(1, 4, 1, 1).to(outputs.device)
# ---> 17     loss = total_loss(outputs, labels)
#      18     test_loss += loss.item()
#      19     pos_true, led_true, dis_true, pos_pred, led_pred, dis_pred = decompose(labels,outputs)
#
# <ipython-input-117-f3bc5487c8e8> in total_loss(y_pred, y_true)
#      29
#      30 def total_loss(y_pred,y_true):
# ---> 31     return pos_loss(y_true, y_pred) + 0.01 * dis_loss(y_true, y_pred) + 0.01 * led_loss(y_true, y_pred)
#
# <ipython-input-117-f3bc5487c8e8> in pos_loss(y_true, y_pred)
#      15 def pos_loss(y_true, y_pred):
#      16     pos_true, led_true, dis_true, pos_pred, led_pred, dis_pred = decompose(y_true, y_pred)
# ---> 17     return torch.mean((pos_true - pos_pred) ** 2)
#      18
#      19 def led_loss(y_true, y_pred):
#
# RuntimeError: The size of tensor a (20) must match the size of tensor b (6) at non-singleton dimension 2

# %%
import quantlib
import quantlib.algorithms as qa
import quantlib.editing.graphs as qg
import quantlib.editing.editing as qe
import quantlib.backends.dory as qd

# %%
model_fp = qg.fx.quantlib_symbolic_trace(root=model)

# Print the graph in tabular format
model_fp.graph.print_tabular()
# Out:
# Proxy(getattr_1)
# Proxy(getattr_2)
# Proxy(getattr_3)
# Proxy(getattr_4)
# Proxy(getattr_5)
# Proxy(getattr_6)
# Proxy(getattr_7)
# opcode         name       target                       args                 kwargs
# -------------  ---------  ---------------------------  -------------------  --------
# placeholder    x          x                            ()                   {}
# call_module    block1_0   block1.0                     (x,)                 {}
# call_module    block1_1   block1.1                     (block1_0,)          {}
# call_module    block1_2   block1.2                     (block1_1,)          {}
# call_module    block1_3   block1.3                     (block1_2,)          {}
# call_module    block1_4   block1.4                     (block1_3,)          {}
# call_module    block1_5   block1.5                     (block1_4,)          {}
# call_function  getattr_1  <built-in function getattr>  (block1_5, 'shape')  {}
# call_module    avgpool1   avgpool1                     (block1_5,)          {}
# call_function  getattr_2  <built-in function getattr>  (avgpool1, 'shape')  {}
# call_module    block2_0   block2.0                     (avgpool1,)          {}
# call_module    block2_1   block2.1                     (block2_0,)          {}
# call_module    block2_2   block2.2                     (block2_1,)          {}
# call_function  getattr_3  <built-in function getattr>  (block2_2, 'shape')  {}
# call_module    avgpool2   avgpool2                     (block2_2,)          {}
# call_function  getattr_4  <built-in function getattr>  (avgpool2, 'shape')  {}
# call_module    block3_0   block3.0                     (avgpool2,)          {}
# call_module    block3_1   block3.1                     (block3_0,)          {}
# call_module    block3_2   block3.2                     (block3_1,)          {}
# call_function  getattr_5  <built-in function getattr>  (block3_2, 'shape')  {}
# call_module    avgpool3   avgpool3                     (block3_2,)          {}
# call_function  getattr_6  <built-in function getattr>  (avgpool3, 'shape')  {}
# call_module    block4_0   block4.0                     (avgpool3,)          {}
# call_module    block4_1   block4.1                     (block4_0,)          {}
# call_module    block4_2   block4.2                     (block4_1,)          {}
# call_module    block4_3   block4.3                     (block4_2,)          {}
# call_module    block4_4   block4.4                     (block4_3,)          {}
# call_module    block4_5   block4.5                     (block4_4,)          {}
# call_module    block4_6   block4.6                     (block4_5,)          {}
# call_module    block4_7   block4.7                     (block4_6,)          {}
# call_module    block4_8   block4.8                     (block4_7,)          {}
# call_function  getattr_7  <built-in function getattr>  (block4_8, 'shape')  {}
# output         output     output                       (block4_8,)          {}

# %%
#float 2 fake
f2fconverter = qe.float2fake.F2F8bitPACTRoundingConverter()
model_fq = f2fconverter(model_fp)

model_fq_lw = qg.lw.quantlib_traverse(root=model_fq)
model_fq_lw.show()

# set validation state
# model_fq.eval()
# Out:
# 0.block1	PACTConv2d(1, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# 1.block1	BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 2.block1	PACTReLU(inplace=True)
# 3.block1	PACTConv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# 4.block1	BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 5.block1	PACTReLU(inplace=True)
# avgpool1	AdaptiveAvgPool2d(output_size=(2, 2))
# 0.block2	PACTConv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# 1.block2	BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 2.block2	PACTReLU(inplace=True)
# avgpool2	AdaptiveAvgPool2d(output_size=(2, 2))
# 0.block3	PACTConv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# 1.block3	BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 2.block3	PACTReLU(inplace=True)
# avgpool3	AdaptiveAvgPool2d(output_size=(2, 2))
# 0.block4	PACTConv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# 1.block4	BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 2.block4	PACTReLU(inplace=True)
# 3.block4	PACTConv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), padding=(1, 1), bias=False)
# 4.block4	BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 5.block4	PACTReLU(inplace=True)
# 6.block4	PACTConv2d(128, 4, kernel_size=(1, 1), stride=(1, 1), padding=(1, 1), bias=False)
# 7.block4	BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 8.block4	PACTReLU(inplace=True)

# %%
model_fq.graph.print_tabular()
# Out:
# opcode       name      target    args         kwargs
# -----------  --------  --------  -----------  --------
# placeholder  x         x         ()           {}
# call_module  block1_0  block1.0  (x,)         {}
# call_module  block1_1  block1.1  (block1_0,)  {}
# call_module  block1_2  block1.2  (block1_1,)  {}
# call_module  block1_3  block1.3  (block1_2,)  {}
# call_module  block1_4  block1.4  (block1_3,)  {}
# call_module  block1_5  block1.5  (block1_4,)  {}
# call_module  avgpool1  avgpool1  (block1_5,)  {}
# call_module  block2_0  block2.0  (avgpool1,)  {}
# call_module  block2_1  block2.1  (block2_0,)  {}
# call_module  block2_2  block2.2  (block2_1,)  {}
# call_module  avgpool2  avgpool2  (block2_2,)  {}
# call_module  block3_0  block3.0  (avgpool2,)  {}
# call_module  block3_1  block3.1  (block3_0,)  {}
# call_module  block3_2  block3.2  (block3_1,)  {}
# call_module  avgpool3  avgpool3  (block3_2,)  {}
# call_module  block4_0  block4.0  (avgpool3,)  {}
# call_module  block4_1  block4.1  (block4_0,)  {}
# call_module  block4_2  block4.2  (block4_1,)  {}
# call_module  block4_3  block4.3  (block4_2,)  {}
# call_module  block4_4  block4.4  (block4_3,)  {}
# call_module  block4_5  block4.5  (block4_4,)  {}
# call_module  block4_6  block4.6  (block4_5,)  {}
# call_module  block4_7  block4.7  (block4_6,)  {}
# call_module  block4_8  block4.8  (block4_7,)  {}
# output       output    output    (block4_8,)  {}

# %%
def validate(model, device, dataloader, verbose=True, integer=False):
    correct = 0
    total = 0
    test_loss = 0
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for data in dataloader:
            inputs, labels = data
            inputs = inputs.to(device)
            labels = labels.to(device)
            if integer:
                outputs = model(inputs.float())
            else:
                outputs = model(inputs.float() / 255.0)
            outputs = outputs * torch.tensor([1., 1., 3.,1.]).view(1, 4, 1, 1).to(outputs.device)
            loss = total_loss(outputs, labels)
            test_loss += loss.item()
        print(f"Test loss: {test_loss/len(dataloader)}")
    return test_loss/len(dataloader)

# %%
valid_set = get_data("./content/datasets/dataset_test.h5",False,True,8096)
# valid_set = get_data("./content/datasets/dataset_test.h5",False,False,0)
valid_dataset = MyDataset(valid_set[0], valid_set[1])
valid_dataloader = DataLoader(valid_dataset, batch_size=32, shuffle=True)
# Out:
# (8096, 1, 160, 160)
# (8096, 1, 160, 160)
# (8096, 1, 160, 160)
# (8096, 1, 160, 160)
# (8096, 3, 160, 160)

# %%
test_set = get_data("./content/datasets_test_hard/dataset_test_hard.h5",False,False,0)
test_dataset = MyDataset(test_set[0], test_set[1])
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=True)
# Out:
# (4634, 1, 160, 160)
# (4634, 1, 160, 160)
# (4634, 1, 160, 160)
# (4634, 1, 160, 160)
# (4634, 3, 160, 160)

# %%
with qe.float2fake.calibration(model_fq):
    acc = validate(model_fq, device, calib_dataloader)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/quantlib-0.2-py3.8.egg/quantlib/editing/editing/float2fake/__init__.py in calibration(net, verbose)
#     189     try:
# --> 190         yield
#     191     finally:
#
# <ipython-input-124-e5839355d6e1> in <module>
#       1 with qe.float2fake.calibration(model_fq):
# ----> 2     acc = validate(model_fq, device, calib_dataloader)
#
# <ipython-input-37-ab6ff83e37cb> in validate(model, device, dataloader, verbose, integer)
#      15             outputs = outputs * torch.tensor([1., 1., 3.,1.]).view(1, 4, 1, 1).to(outputs.device)
# ---> 16             loss = total_loss(outputs, labels)
#      17             test_loss += loss.item()
#
# <ipython-input-117-f3bc5487c8e8> in total_loss(y_pred, y_true)
#      30 def total_loss(y_pred,y_true):
# ---> 31     return pos_loss(y_true, y_pred) + 0.01 * dis_loss(y_true, y_pred) + 0.01 * led_loss(y_true, y_pred)
#
# <ipython-input-117-f3bc5487c8e8> in pos_loss(y_true, y_pred)
#      16     pos_true, led_true, dis_true, pos_pred, led_pred, dis_pred = decompose(y_true, y_pred)
# ---> 17     return torch.mean((pos_true - pos_pred) ** 2)
#      18
#
# RuntimeError: The size of tensor a (20) must match the size of tensor b (6) at non-singleton dimension 2
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-e5839355d6e1> in <module>
#       1 with qe.float2fake.calibration(model_fq):
# ----> 2     acc = validate(model_fq, device, calib_dataloader)
#
# ~/miniconda3/envs/quantlab/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     129                 value = type()
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#     133                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/quantlib-0.2-py3.8.egg/quantlib/editing/editing/float2fake/__init__.py in calibration(net, verbose)
#     194         for m in net.modules():
#     195             if isinstance(m, tuple(qa.qalgorithms.qatalgorithms.pact.NNMODULE_TO_PACTMODULE.values())):
# --> 196                 m.stop_observing()
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/quantlib-0.2-py3.8.egg/quantlib/algorithms/qmodules/qmodules/qmodules.py in stop_observing(self)
#     295     def stop_observing(self):
#     296         self._is_observing &= False
# --> 297         self.init_qhparams()
#     298
#     299     def _register_qop(self):
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/quantlib-0.2-py3.8.egg/quantlib/algorithms/qmodules/qmodules/qmodules.py in init_qhparams(self)
#     286         self._observer = MinMaxMeanVarObserver(self._qgranularity)
#     287         self._observer.update(self.weight)  # resolve broadcasting shape
# --> 288         self._init_qhparams()
#     289         self._set_clipping_bounds()
#     290         self._observer = MinMaxMeanVarObserver(self._qgranularity)
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/quantlib-0.2-py3.8.egg/quantlib/algorithms/qmodules/qmodules/qmodules.py in _init_qhparams(self)
#     102         a, b = self._qinitstrategy.get_a_b(self._observer)
#     103         if self._pin_offset:
# --> 104             scale = get_scale(a, b, self.zero, self.n_levels, self.step)
#     105             self.scale.data.copy_(scale.to(device=self.scale.device))
#     106         else:
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/quantlib-0.2-py3.8.egg/quantlib/algorithms/qbase/qhparams/qhparams.py in get_scale(a, b, zero, n_levels, step)
#     130               step: torch.Tensor) -> torch.Tensor:
#     131     """Compute the quantum of a quantisation range with fixed offset."""
# --> 132     _check_a_b(a, b)
#     133
#     134     # TODO: find a more elegant way to ensure that the parameters are on the same device (attribute this responsibility to the right objects)
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/quantlib-0.2-py3.8.egg/quantlib/algorithms/qbase/qhparams/qhparams.py in _check_a_b(a, b)
#      81     if not torch.all(a < b):
#      82         caller_name = inspect.getouterframes(inspect.currentframe())[1].function    # https://stackoverflow.com/a/2529895 and https://docs.python.org/3/library/inspect.html#inspect.getouterframes
# ---> 83         raise ValueError(quantlib_err_header(obj_name=caller_name) + f"requires that all the components of {a} are strictly lower than the corresponding components of {b}.")
#      84
#      85
#
# ValueError: [QuantLib error] get_scale: requires that all the components of tensor([[[[nan]]],
#
#
#         [[[nan]]],
#
#
#         [[[nan]]],
#
#
#         [[[nan]]]], grad_fn=<ViewBackward>) are strictly lower than the corresponding components of tensor([[[[nan]]],
#
#
#         [[[nan]]],
#
#
#         [[[nan]]],
#
#
#         [[[nan]]]], grad_fn=<ViewBackward>).

# %%
# adds rounding to all PACT operators
rounder =  qe.float2fake.F2F8bitPACTRounder()
model_fq_rounded = rounder(model_fq)
model_fq_rounded.to(device)
model_fq_rounded.eval()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-15f308e55b24> in <module>
#       1 # adds rounding to all PACT operators
#       2 rounder =  qe.float2fake.F2F8bitPACTRounder()
# ----> 3 model_fq_rounded = rounder(model_fq)
#       4 model_fq_rounded.to(device)
#       5 model_fq_rounded.eval()
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/quantlib-0.2-py3.8.egg/quantlib/editing/editing/editors/base/editor.py in __call__(self, g, *args, **kwargs)
#      30
#      31     def __call__(self, g: fx.GraphModule, *args, **kwargs) -> fx.GraphModule:
# ---> 32         return self.apply(g, *args, **kwargs)
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/quantlib-0.2-py3.8.egg/quantlib/editing/editing/editors/base/composededitor.py in apply(self, g, *args, **kwargs)
#      39
#      40         for editor in self._children_editors:
# ---> 41             g = editor(g, *args, **kwargs)
#      42
#      43         return g
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/quantlib-0.2-py3.8.egg/quantlib/editing/editing/editors/base/editor.py in __call__(self, g, *args, **kwargs)
#      30
#      31     def __call__(self, g: fx.GraphModule, *args, **kwargs) -> fx.GraphModule:
# ---> 32         return self.apply(g, *args, **kwargs)
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/quantlib-0.2-py3.8.egg/quantlib/editing/editing/editors/base/composededitor.py in apply(self, g, *args, **kwargs)
#      39
#      40         for editor in self._children_editors:
# ---> 41             g = editor(g, *args, **kwargs)
#      42
#      43         return g
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/quantlib-0.2-py3.8.egg/quantlib/editing/editing/editors/base/editor.py in __call__(self, g, *args, **kwargs)
#      30
#      31     def __call__(self, g: fx.GraphModule, *args, **kwargs) -> fx.GraphModule:
# ---> 32         return self.apply(g, *args, **kwargs)
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/quantlib-0.2-py3.8.egg/quantlib/editing/editing/editors/base/rewriter/rewriter.py in apply(self, g, apcontexts, *args, **kwargs)
#      89         # rewrite all the application points
#      90         for apc in apcontexts:
# ---> 91             g = self._applier.apply(g, apc.ap, self.id_)
#      92
#      93         return g
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/quantlib-0.2-py3.8.egg/quantlib/editing/editing/editors/base/rewriter/applier.py in apply(self, g, ap, id_)
#      52
#      53         # modify the graph
# ---> 54         g = self._apply(g, ap, id_)
#      55         Applier._polish_fxgraphmodule(g)
#      56
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/quantlib-0.2-py3.8.egg/quantlib/editing/editing/float2fake/quantisation/weightrounder/applier.py in _apply(self, g, ap, id_)
#      47         rounding = (module_linear.scale.data.detach().clone()) * 0.5
#      48         module_linear.weight.data  += torch.as_tensor(rounding, device=module_linear.weight.device)
# ---> 49         module_linear.init_qhparams()
#      50
#      51         return g
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/quantlib-0.2-py3.8.egg/quantlib/algorithms/qmodules/qmodules/qmodules.py in init_qhparams(self)
#     286         self._observer = MinMaxMeanVarObserver(self._qgranularity)
#     287         self._observer.update(self.weight)  # resolve broadcasting shape
# --> 288         self._init_qhparams()
#     289         self._set_clipping_bounds()
#     290         self._observer = MinMaxMeanVarObserver(self._qgranularity)
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/quantlib-0.2-py3.8.egg/quantlib/algorithms/qmodules/qmodules/qmodules.py in _init_qhparams(self)
#     102         a, b = self._qinitstrategy.get_a_b(self._observer)
#     103         if self._pin_offset:
# --> 104             scale = get_scale(a, b, self.zero, self.n_levels, self.step)
#     105             self.scale.data.copy_(scale.to(device=self.scale.device))
#     106         else:
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/quantlib-0.2-py3.8.egg/quantlib/algorithms/qbase/qhparams/qhparams.py in get_scale(a, b, zero, n_levels, step)
#     130               step: torch.Tensor) -> torch.Tensor:
#     131     """Compute the quantum of a quantisation range with fixed offset."""
# --> 132     _check_a_b(a, b)
#     133
#     134     # TODO: find a more elegant way to ensure that the parameters are on the same device (attribute this responsibility to the right objects)
#
# ~/miniconda3/envs/quantlab/lib/python3.8/site-packages/quantlib-0.2-py3.8.egg/quantlib/algorithms/qbase/qhparams/qhparams.py in _check_a_b(a, b)
#      81     if not torch.all(a < b):
#      82         caller_name = inspect.getouterframes(inspect.currentframe())[1].function    # https://stackoverflow.com/a/2529895 and https://docs.python.org/3/library/inspect.html#inspect.getouterframes
# ---> 83         raise ValueError(quantlib_err_header(obj_name=caller_name) + f"requires that all the components of {a} are strictly lower than the corresponding components of {b}.")
#      84
#      85
#
# ValueError: [QuantLib error] get_scale: requires that all the components of tensor([[[[nan]]],
#
#
#         [[[nan]]],
#
#
#         [[[nan]]],
#
#
#         [[[nan]]]], grad_fn=<ViewBackward>) are strictly lower than the corresponding components of tensor([[[[nan]]],
#
#
#         [[[nan]]],
#
#
#         [[[nan]]],
#
#
#         [[[nan]]]], grad_fn=<ViewBackward>).

# %%
acc = validate(model_fq_rounded, device, valid_dataloader)
print("\nFakeQuantized with calibration+rounding: loss: %.3f" % (acc))
# Out:
# Test loss: 0.005393728759257572
#
# FakeQuantized with calibration+rounding: loss: 0.005

# %%
x, _ = next(iter(calib_dataloader))
x=x.float()
x = x[0].unsqueeze(0)
print(x.dtype)
f2tconverter = qe.f2t.F2T24bitConverter()
model_tq = f2tconverter(model_fq_rounded, {'x': {'shape': x.shape, 'scale': torch.tensor((0.0039216,))}})
# Out:
# torch.float32
# /Users/lambe/miniconda3/envs/quantlab/lib/python3.8/site-packages/torch/fx/graph.py:606: UserWarning: Attempted to insert a call_module Node with no underlying reference in the owning GraphModule! Call GraphModule.add_submodule to add the necessary submodule
#   warnings.warn("Attempted to insert a call_module Node with "

# %%
model_tq.graph.print_tabular()
# Out:
# opcode       name                                                   target                                             args                                                      kwargs
# -----------  -----------------------------------------------------  -------------------------------------------------  --------------------------------------------------------  --------
# placeholder  x                                                      x                                                  ()                                                        {}
# call_module  ql_eps_qconv2d_eps_integeriser_140690270908816__21_    QL_EpsQConv2dEpsIntegeriser_140690270908816__21_   (x,)                                                      {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140690255635120__7_  QL_EpsBN2dQReLUEpsRequantiser_140690255635120__7_  (ql_eps_qconv2d_eps_integeriser_140690270908816__21_,)    {}
# call_module  ql_eps_qconv2d_eps_integeriser_140690270908816__20_    QL_EpsQConv2dEpsIntegeriser_140690270908816__20_   (ql_eps_bn2d_qre_lueps_requantiser_140690255635120__7_,)  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140690255635120__6_  QL_EpsBN2dQReLUEpsRequantiser_140690255635120__6_  (ql_eps_qconv2d_eps_integeriser_140690270908816__20_,)    {}
# call_module  pool1                                                  pool1                                              (ql_eps_bn2d_qre_lueps_requantiser_140690255635120__6_,)  {}
# call_module  ql_eps_qconv2d_eps_integeriser_140690270908816__19_    QL_EpsQConv2dEpsIntegeriser_140690270908816__19_   (pool1,)                                                  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140690255635120__5_  QL_EpsBN2dQReLUEpsRequantiser_140690255635120__5_  (ql_eps_qconv2d_eps_integeriser_140690270908816__19_,)    {}
# call_module  pool2                                                  pool2                                              (ql_eps_bn2d_qre_lueps_requantiser_140690255635120__5_,)  {}
# call_module  ql_eps_qconv2d_eps_integeriser_140690270908816__18_    QL_EpsQConv2dEpsIntegeriser_140690270908816__18_   (pool2,)                                                  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140690255635120__4_  QL_EpsBN2dQReLUEpsRequantiser_140690255635120__4_  (ql_eps_qconv2d_eps_integeriser_140690270908816__18_,)    {}
# call_module  pool3                                                  pool3                                              (ql_eps_bn2d_qre_lueps_requantiser_140690255635120__4_,)  {}
# call_module  ql_eps_qconv2d_eps_integeriser_140690270908816__17_    QL_EpsQConv2dEpsIntegeriser_140690270908816__17_   (pool3,)                                                  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140690255635120__3_  QL_EpsBN2dQReLUEpsRequantiser_140690255635120__3_  (ql_eps_qconv2d_eps_integeriser_140690270908816__17_,)    {}
# call_module  ql_eps_qconv2d_eps_integeriser_140690270908816__16_    QL_EpsQConv2dEpsIntegeriser_140690270908816__16_   (ql_eps_bn2d_qre_lueps_requantiser_140690255635120__3_,)  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140690255635120__2_  QL_EpsBN2dQReLUEpsRequantiser_140690255635120__2_  (ql_eps_qconv2d_eps_integeriser_140690270908816__16_,)    {}
# call_module  ql_eps_qconv2d_eps_integeriser_140690270908816__15_    QL_EpsQConv2dEpsIntegeriser_140690270908816__15_   (ql_eps_bn2d_qre_lueps_requantiser_140690255635120__2_,)  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140690255635120__1_  QL_EpsBN2dQReLUEpsRequantiser_140690255635120__1_  (ql_eps_qconv2d_eps_integeriser_140690270908816__15_,)    {}
# call_module  ql_eps_tunnel_inserter_140690270910160__18_            QL_EpsTunnelInserter_140690270910160__18_          (ql_eps_bn2d_qre_lueps_requantiser_140690255635120__1_,)  {}
# output       output                                                 output                                             (ql_eps_tunnel_inserter_140690270910160__18_,)            {}

# %%
# Test the network
acc = validate(model_tq, device, valid_dataloader, integer=True)
print("\nTrueQuantized: accuracy: %.3f" % (acc))
# Out:
# Test loss: 0.005394605838734171
#
# TrueQuantized: accuracy: 0.005

# %%
epsremover = qe.f2t.FinalEpsTunnelRemover()
model_tq_removed = epsremover(model_tq)
model_tq_removed.graph.print_tabular()
# Out:
# [FinalEpsTunnelRemover] output: removing EpsTunnel with scaling factor tensor([0.0003106381918769])
# [FinalEpsTunnelRemover] output: outputs will need to be scaled *externally* to maintain program semantics.
# opcode       name                                                   target                                             args                                                      kwargs
# -----------  -----------------------------------------------------  -------------------------------------------------  --------------------------------------------------------  --------
# placeholder  x                                                      x                                                  ()                                                        {}
# call_module  ql_eps_qconv2d_eps_integeriser_140690270908816__21_    QL_EpsQConv2dEpsIntegeriser_140690270908816__21_   (x,)                                                      {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140690255635120__7_  QL_EpsBN2dQReLUEpsRequantiser_140690255635120__7_  (ql_eps_qconv2d_eps_integeriser_140690270908816__21_,)    {}
# call_module  ql_eps_qconv2d_eps_integeriser_140690270908816__20_    QL_EpsQConv2dEpsIntegeriser_140690270908816__20_   (ql_eps_bn2d_qre_lueps_requantiser_140690255635120__7_,)  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140690255635120__6_  QL_EpsBN2dQReLUEpsRequantiser_140690255635120__6_  (ql_eps_qconv2d_eps_integeriser_140690270908816__20_,)    {}
# call_module  pool1                                                  pool1                                              (ql_eps_bn2d_qre_lueps_requantiser_140690255635120__6_,)  {}
# call_module  ql_eps_qconv2d_eps_integeriser_140690270908816__19_    QL_EpsQConv2dEpsIntegeriser_140690270908816__19_   (pool1,)                                                  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140690255635120__5_  QL_EpsBN2dQReLUEpsRequantiser_140690255635120__5_  (ql_eps_qconv2d_eps_integeriser_140690270908816__19_,)    {}
# call_module  pool2                                                  pool2                                              (ql_eps_bn2d_qre_lueps_requantiser_140690255635120__5_,)  {}
# call_module  ql_eps_qconv2d_eps_integeriser_140690270908816__18_    QL_EpsQConv2dEpsIntegeriser_140690270908816__18_   (pool2,)                                                  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140690255635120__4_  QL_EpsBN2dQReLUEpsRequantiser_140690255635120__4_  (ql_eps_qconv2d_eps_integeriser_140690270908816__18_,)    {}
# call_module  pool3                                                  pool3                                              (ql_eps_bn2d_qre_lueps_requantiser_140690255635120__4_,)  {}
# call_module  ql_eps_qconv2d_eps_integeriser_140690270908816__17_    QL_EpsQConv2dEpsIntegeriser_140690270908816__17_   (pool3,)                                                  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140690255635120__3_  QL_EpsBN2dQReLUEpsRequantiser_140690255635120__3_  (ql_eps_qconv2d_eps_integeriser_140690270908816__17_,)    {}
# call_module  ql_eps_qconv2d_eps_integeriser_140690270908816__16_    QL_EpsQConv2dEpsIntegeriser_140690270908816__16_   (ql_eps_bn2d_qre_lueps_requantiser_140690255635120__3_,)  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140690255635120__2_  QL_EpsBN2dQReLUEpsRequantiser_140690255635120__2_  (ql_eps_qconv2d_eps_integeriser_140690270908816__16_,)    {}
# call_module  ql_eps_qconv2d_eps_integeriser_140690270908816__15_    QL_EpsQConv2dEpsIntegeriser_140690270908816__15_   (ql_eps_bn2d_qre_lueps_requantiser_140690255635120__2_,)  {}
# call_module  ql_eps_bn2d_qre_lueps_requantiser_140690255635120__1_  QL_EpsBN2dQReLUEpsRequantiser_140690255635120__1_  (ql_eps_qconv2d_eps_integeriser_140690270908816__15_,)    {}
# output       output                                                 output                                             (ql_eps_bn2d_qre_lueps_requantiser_140690255635120__1_,)  {}

# %%
test_loss = 0.0
correct = 0
total = 0
model_tq_removed.eval()  # set model to evaluation mode


fig_in, ax_in = plt.subplots(11, 3, figsize=(30, 110))
ax_in = ax_in.flatten()

with torch.no_grad():
    # get a single batch of data from test dataloader
    data = next(iter(test_dataloader))
    inputs, labels = data
    inputs = inputs.to(device)
    labels = labels.to(device)
    outputs = model_tq_removed(inputs.float())
    outputs = outputs * torch.tensor([1., 1., 3.]).view(1, 3, 1, 1).to(outputs.device)
    loss = total_loss(outputs, labels)
    test_loss += loss.item()
    pos_true, led_true, dis_true, pos_pred, led_pred, dis_pred = decompose(labels,outputs)
    for i in range(0,inputs.shape[0],3):
        ax_in[i].imshow(inputs[i][0].cpu(),cmap="gray")
        ax_in[i+1].imshow(pos_true[i].cpu(),cmap="gray")
        ax_in[i+2].imshow(pos_pred[i].cpu(),cmap="gray")
    #   

print(f"Test loss: {test_loss}")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-b135477480d0> in <module>
#      10 with torch.no_grad():
#      11     # get a single batch of data from test dataloader
# ---> 12     data = next(iter(test_dataloader))
#      13     inputs, labels = data
#      14     inputs = inputs.to(device)
#
# NameError: name 'test_dataloader' is not defined

# %%
print(model_tq_removed)
# Out:
# MkModel(
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (QL_EpsQConv2dEpsIntegeriser_140690115633744__1_): Conv2d(128, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (QL_EpsQConv2dEpsIntegeriser_140690115633744__2_): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (QL_EpsQConv2dEpsIntegeriser_140690115633744__3_): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (QL_EpsQConv2dEpsIntegeriser_140690115633744__4_): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (QL_EpsQConv2dEpsIntegeriser_140690115633744__5_): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (QL_EpsQConv2dEpsIntegeriser_140690115633744__6_): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (QL_EpsQConv2dEpsIntegeriser_140690115633744__7_): Conv2d(1, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (QL_EpsBN2dQReLUEpsRequantiser_140690115475680__1_): Requantisation()
#   (QL_EpsBN2dQReLUEpsRequantiser_140690115475680__2_): Requantisation()
#   (QL_EpsBN2dQReLUEpsRequantiser_140690115475680__3_): Requantisation()
#   (QL_EpsBN2dQReLUEpsRequantiser_140690115475680__4_): Requantisation()
#   (QL_EpsBN2dQReLUEpsRequantiser_140690115475680__5_): Requantisation()
#   (QL_EpsBN2dQReLUEpsRequantiser_140690115475680__6_): Requantisation()
#   (QL_EpsBN2dQReLUEpsRequantiser_140690115475680__7_): Requantisation()
# )
#
# def forward(self, x):
#     ql_eps_qconv2d_eps_integeriser_140690115633744__7_ = self.QL_EpsQConv2dEpsIntegeriser_140690115633744__7_(x);  x = None
#     ql_eps_bn2d_qre_lueps_requantiser_140690115475680__7_ = self.QL_EpsBN2dQReLUEpsRequantiser_140690115475680__7_(ql_eps_qconv2d_eps_integeriser_140690115633744__7_);  ql_eps_qconv2d_eps_integeriser_140690115633744__7_ = None
#     ql_eps_qconv2d_eps_integeriser_140690115633744__6_ = self.QL_EpsQConv2dEpsIntegeriser_140690115633744__6_(ql_eps_bn2d_qre_lueps_requantiser_140690115475680__7_);  ql_eps_bn2d_qre_lueps_requantiser_140690115475680__7_ = None
#     ql_eps_bn2d_qre_lueps_requantiser_140690115475680__6_ = self.QL_EpsBN2dQReLUEpsRequantiser_140690115475680__6_(ql_eps_qconv2d_eps_integeriser_140690115633744__6_);  ql_eps_qconv2d_eps_integeriser_140690115633744__6_ = None
#     pool1 = self.pool1(ql_eps_bn2d_qre_lueps_requantiser_140690115475680__6_);  ql_eps_bn2d_qre_lueps_requantiser_140690115475680__6_ = None
#     ql_eps_qconv2d_eps_integeriser_140690115633744__5_ = self.QL_EpsQConv2dEpsIntegeriser_140690115633744__5_(pool1);  pool1 = None
#     ql_eps_bn2d_qre_lueps_requantiser_140690115475680__5_ = self.QL_EpsBN2dQReLUEpsRequantiser_140690115475680__5_(ql_eps_qconv2d_eps_integeriser_140690115633744__5_);  ql_eps_qconv2d_eps_integeriser_140690115633744__5_ = None
#     pool2 = self.pool2(ql_eps_bn2d_qre_lueps_requantiser_140690115475680__5_);  ql_eps_bn2d_qre_lueps_requantiser_140690115475680__5_ = None
#     ql_eps_qconv2d_eps_integeriser_140690115633744__4_ = self.QL_EpsQConv2dEpsIntegeriser_140690115633744__4_(pool2);  pool2 = None
#     ql_eps_bn2d_qre_lueps_requantiser_140690115475680__4_ = self.QL_EpsBN2dQReLUEpsRequantiser_140690115475680__4_(ql_eps_qconv2d_eps_integeriser_140690115633744__4_);  ql_eps_qconv2d_eps_integeriser_140690115633744__4_ = None
#     pool3 = self.pool3(ql_eps_bn2d_qre_lueps_requantiser_140690115475680__4_);  ql_eps_bn2d_qre_lueps_requantiser_140690115475680__4_ = None
#     ql_eps_qconv2d_eps_integeriser_140690115633744__3_ = self.QL_EpsQConv2dEpsIntegeriser_140690115633744__3_(pool3);  pool3 = None
#     ql_eps_bn2d_qre_lueps_requantiser_140690115475680__3_ = self.QL_EpsBN2dQReLUEpsRequantiser_140690115475680__3_(ql_eps_qconv2d_eps_integeriser_140690115633744__3_);  ql_eps_qconv2d_eps_integeriser_140690115633744__3_ = None
#     ql_eps_qconv2d_eps_integeriser_140690115633744__2_ = self.QL_EpsQConv2dEpsIntegeriser_140690115633744__2_(ql_eps_bn2d_qre_lueps_requantiser_140690115475680__3_);  ql_eps_bn2d_qre_lueps_requantiser_140690115475680__3_ = None
#     ql_eps_bn2d_qre_lueps_requantiser_140690115475680__2_ = self.QL_EpsBN2dQReLUEpsRequantiser_140690115475680__2_(ql_eps_qconv2d_eps_integeriser_140690115633744__2_);  ql_eps_qconv2d_eps_integeriser_140690115633744__2_ = None
#     ql_eps_qconv2d_eps_integeriser_140690115633744__1_ = self.QL_EpsQConv2dEpsIntegeriser_140690115633744__1_(ql_eps_bn2d_qre_lueps_requantiser_140690115475680__2_);  ql_eps_bn2d_qre_lueps_requantiser_140690115475680__2_ = None
#     ql_eps_bn2d_qre_lueps_requantiser_140690115475680__1_ = self.QL_EpsBN2dQReLUEpsRequantiser_140690115475680__1_(ql_eps_qconv2d_eps_integeriser_140690115633744__1_);  ql_eps_qconv2d_eps_integeriser_140690115633744__1_ = None
#     return ql_eps_bn2d_qre_lueps_requantiser_140690115475680__1_

# %%
doryexporter = qd.DORYExporter()
doryexporter.export(model_tq_removed, x.shape, ".")
doryexporter.dump_features(model_tq, x, ".")

# %%
mgX40, mgY40 = np.meshgrid(np.linspace(0,1,20), np.linspace(0,1,20))
def postprocess_simple_batch(labels, outputs):
    pos_true, led_true, dis_true, pos_predi, led_predi, dis_predi = decompose(labels,outputs)
    pos_truei=pos_true.cpu().detach().numpy()
    led_truei=led_true.cpu().detach().numpy()
    dis_truei=dis_true.cpu().detach().numpy()
    pos_predi=pos_predi.cpu().detach().numpy()
    led_predi=led_predi.cpu().detach().numpy()
    dis_predi=dis_predi.cpu().detach().numpy()

    # a=dis_pred[i]*pos_pred[i]
    # a=a.cpu().detach().numpy()
    # b=pos_pred[i].cpu().detach().numpy()
    # dis_pred_val = np.sum(a)/np.sum(b)
    threshold = np.max(pos_predi, axis = (1,2), keepdims = True) * .4
    # print(threshold)
    pos_predi -= threshold
    np.clip(pos_predi, 0, threshold, out = pos_predi)
    pos_predj=pos_predi
    # print(np.sum(dis_predi * pos_predi, axis=(1,2))/np.sum(pos_predi, axis=(1,2)))
    # print(np.sum(dis_truei * pos_truei, axis=(1,2))/np.sum(pos_truei, axis=(1,2)))
  
    
    # print(dis_true)
    ret = dict(
        x_pred = np.sum(mgX40[np.newaxis,:,:] * pos_predi, axis=(1,2))/np.sum(pos_predi, axis=(1,2)) * 160,
        y_pred = np.sum(mgY40[np.newaxis,:,:] * pos_predi, axis=(1,2))/np.sum(pos_predi, axis=(1,2)) * 160,
        led_pred = np.sum(led_predi * pos_predj, axis=(1,2))/np.sum(pos_predj, axis=(1,2)),
        dis_pred = np.sum(dis_predi * pos_predj, axis=(1,2))/np.sum(pos_predj, axis=(1,2)),
        pred_confidence = np.max(pos_predi, axis=(1,2)),
        x_true = np.sum(mgX40[np.newaxis,:,:] * pos_truei, axis=(1,2))/np.sum(pos_truei, axis=(1,2)) * 160,
        y_true = np.sum(mgY40[np.newaxis,:,:] * pos_truei, axis=(1,2))/np.sum(pos_truei, axis=(1,2)) * 160,
        led_true = np.sum(led_truei * pos_truei, axis=(1,2))/np.sum(pos_truei, axis=(1,2)),
        dis_true = np.sum(dis_truei * pos_truei, axis=(1,2))/np.sum(pos_truei, axis=(1,2)),
    )
    return [dict(zip(ret,t)) for t in zip(*ret.values())]

# %%
data_out = []
with torch.no_grad():
    for data in valid_dataloader:
        inputs, labels = data
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model_tq_removed(inputs.float())
        outputs = outputs * torch.tensor([1., 1., 3.]).view(1, 3, 1, 1).to(outputs.device)
        data_out += postprocess_simple_batch(labels,outputs)

# %%
import pandas as pd
df = pd.DataFrame(data_out)
df["y_zone"] = (df["y_true"]/320*3).astype(int)
df["pred_confidence_bin"] = (df["pred_confidence"]*2.99).astype(int)

# %%
import sklearn
import sklearn.metrics
fig,axs = plt.subplots(ncols=3, figsize=(10,3))
alpha = 0.1
axs[0].scatter(df["x_true"],df["x_pred"], s=1, marker='.', alpha=alpha)
axs[0].plot([0,160],[0,160],'k:')
axs[0].set_title(f"u: R2 {sklearn.metrics.r2_score(df['x_true'],df['x_pred']):.03f}")
axs[1].scatter(df["y_true"],df["y_pred"], s=1, marker='.', alpha=alpha)
axs[1].plot([0,160],[0,160],'k:')
axs[1].set_title(f"v: R2 {sklearn.metrics.r2_score(df['y_true'],df['y_pred']):.03f}")
axs[2].scatter(df["dis_true"],df["dis_pred"], s=1, marker='.', alpha=alpha)
axs[2].plot([0.4,1.6],[0.4,1.6],'k:')
axs[2].set_title(f"d: R2 {sklearn.metrics.r2_score(df['dis_true'],df['dis_pred']):.03f}")
# Out:
# Text(0.5, 1.0, 'd: R2 0.405')

# %%
import matplotlib
from matplotlib.pyplot import figure
font = {'family' : 'normal',
'weight' : 'bold',
'size'   : 14}

matplotlib.rc('font', **font)
figure(figsize=(8,8), dpi=80)
plt.title("distance")
plt.xlim([0.2, 1.6])
plt.ylim([0.2, 1.6])
plt.plot(df["dis_true"],df["dis_true"], c ="green")
plt.scatter(df["dis_true"],df["dis_pred"], c ="red", alpha=0.1)
plt.show()
figure(figsize=(8,8), dpi=80)
plt.title("v image")
plt.xlim([0, 160])
plt.ylim([0, 160])
plt.plot(df["y_true"],df["y_true"], c ="green")
plt.scatter(df["y_true"], df["y_pred"], c ="red", alpha=0.1)
plt.show()
figure(figsize=(8,8), dpi=80)
plt.title("u image")
plt.xlim([0, 160])
plt.ylim([0, 160])
plt.plot(df["x_true"], df["x_true"], c ="green")
plt.scatter(df["x_true"], df["x_pred"], c ="red", alpha=0.1)
plt.show()
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
data_out = []
with torch.no_grad():
    for data in test_dataloader:
        inputs, labels = data
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model_tq_removed(inputs.float())
        outputs = outputs * torch.tensor([1., 1., 3.]).view(1, 3, 1, 1).to(outputs.device)
        data_out += postprocess_simple_batch(labels,outputs)

# %%
import pandas as pd
df = pd.DataFrame(data_out)
df["y_zone"] = (df["y_true"]/320*3).astype(int)
df["pred_confidence_bin"] = (df["pred_confidence"]*2.99).astype(int)

# %%
import sklearn
import sklearn.metrics
fig,axs = plt.subplots(ncols=3, figsize=(10,3))
alpha = 0.1
axs[0].scatter(df["x_true"],df["x_pred"], s=1, marker='.', alpha=alpha)
axs[0].plot([0,160],[0,160],'k:')
axs[0].set_title(f"u: R2 {sklearn.metrics.r2_score(df['x_true'],df['x_pred']):.03f}")
axs[1].scatter(df["y_true"],df["y_pred"], s=1, marker='.', alpha=alpha)
axs[1].plot([0,160],[0,160],'k:')
axs[1].set_title(f"v: R2 {sklearn.metrics.r2_score(df['y_true'],df['y_pred']):.03f}")
axs[2].scatter(df["dis_true"],df["dis_pred"], s=1, marker='.', alpha=alpha)
axs[2].plot([0.4,1.6],[0.4,1.6],'k:')
axs[2].set_title(f"d: R2 {sklearn.metrics.r2_score(df['dis_true'],df['dis_pred']):.03f}")
# Out:
# Text(0.5, 1.0, 'd: R2 0.379')

# %%
import matplotlib
from matplotlib.pyplot import figure
font = {'family' : 'normal',
'weight' : 'bold',
'size'   : 14}

matplotlib.rc('font', **font)
figure(figsize=(8,8), dpi=80)
plt.title("distance")
plt.xlim([0.2, 1.6])
plt.ylim([0.2, 1.6])
plt.plot(df["dis_true"],df["dis_true"], c ="green")
plt.scatter(df["dis_true"],df["dis_pred"], c ="red", alpha=0.1)
plt.show()
figure(figsize=(8,8), dpi=80)
plt.title("u image")
plt.xlim([0, 160])
plt.ylim([0, 160])
plt.plot(df["y_true"],df["y_true"], c ="green")
plt.scatter(df["y_true"], df["y_pred"], c ="red", alpha=0.1)
plt.show()
figure(figsize=(8,8), dpi=80)
plt.title("v image")
plt.xlim([0, 160])
plt.ylim([0, 160])
plt.plot(df["x_true"], df["x_true"], c ="green")
plt.scatter(df["x_true"], df["x_pred"], c ="red", alpha=0.1)
plt.show()
